# %%
import sys
# !conda install --yes --prefix {sys.prefix} numpy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
print("*" * 35)
print("DATA INPUTAN")
print("*" * 35)

nis = input("\nNIS : ")
nama = input("Nama : ")
jk = input("Jenis Kelamin : ")
rombel = input("Rombel :")

nilai_bindo = int(input("\nNilai Bahasa Indonesia : "))
nilai_mtk = int(input("Nilai Matematika : "))
nilai_bingg = int(input("Nilai Bahasa Inggris : "))
hasil()

print("\n"+"*" * 35)


print("\nLAPORAN HASIL NILAI AKHIR SEMESTER")
print("SMK WIKRAMA BOGOR")
print("\n----------DATA DIRI----------")


avg = (nilai_bindo + nilai_mtk + nilai_bingg) / 3
if avg>=75 :
    ket = "Lulus"
else :
    ket = "Tidak Lulus"

    
print("Nis : ", nis)
print("Nama : ", nama)
print("Jenis Kelamin : ", jk)

print("\n----------NILAI----------")

print("Bahasa Indonesia : ", nilai_bindo)
print("Matematika : ", nilai_mtk)
print("Bahasa Inggris : ", nilai_bingg)
print("Rata-rata Nilai : ", avg)
print("Kriteria Kelulusan : ", ket)
# Out:
# ***********************************
# DATA INPUTAN
# ***********************************
#
# NIS : 2121
# Nama : akbar
# Jenis Kelamin : jk
# Rombel :kk
#
# Nilai Bahasa Indonesia : 90
# Nilai Matematika : 89
# Nilai Bahasa Inggris : 87
#
# LAPORAN HASIL NILAI AKHIR SEMESTER
# SMK WIKRAMA BOGOR
#
# ----------DATA DIRI----------
# Nis :  2121
# Nama :  akbar
# Jenis Kelamin :  jk
#
# ----------NILAI----------
# Bahasa Indonesia :  90
# Matematika :  89
# Bahasa Inggris :  87
# Rata-rata Nilai :  88.66666666666667
# Kriteria Kelulusan :  Lulus
#
# ***********************************
#
# LAPORAN HASIL NILAI AKHIR SEMESTER
# SMK WIKRAMA BOGOR
#
# ----------DATA DIRI----------
# Nis :  2121
# Nama :  akbar
# Jenis Kelamin :  jk
#
# ----------NILAI----------
# Bahasa Indonesia :  90
# Matematika :  89
# Bahasa Inggris :  87
# Rata-rata Nilai :  88.66666666666667
# Kriteria Kelulusan :  Lulus

# %%
import sys

def data():
    print("*" * 35)
    print("DATA INPUTAN")
    print("*" * 35)

    nis = input("\nNIS : ")
    nama = input("Nama : ")
    jk = input("Jenis Kelamin : ")
    rombel = input("Rombel :")

    nilai_bindo = int(input("\nNilai Bahasa Indonesia : "))
    nilai_mtk = int(input("Nilai Matematika : "))
    nilai_bingg = int(input("Nilai Bahasa Inggris : "))
    hasil()

# print("\n"+"*" * 35)

def hasil():
    print("\nLAPORAN HASIL NILAI AKHIR SEMESTER")
    print("SMK WIKRAMA BOGOR")
    print("\n----------DATA DIRI----------")

    avg = (nilai_bindo + nilai_mtk + nilai_bingg) / 3
    if avg>=75 :
        ket = "Lulus"
    else :
        ket = "Tidak Lulus"

    print("Nis : ", nis)
    print("Nama : ", nama)
    print("Jenis Kelamin : ", jk)

    print("\n----------NILAI----------")

    print("Bahasa Indonesia : ", nilai_bindo)
    print("Matematika : ", nilai_mtk)
    print("Bahasa Inggris : ", nilai_bingg)
    print("Rata-rata Nilai : ", avg)
    print("Kriteria Kelulusan : ", ket)

def tanya():
    print("\n--------------------")
    tanya = input("Ingin menginput data ? [y/t]")
    if tanya == "y" :
        data()
    elif tanya == "t" :
        sys.exit()
    else :
        print("Maaf, Pilihan yang anda masukkan tidak sesuai")
